# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# creating variables for the three data urls
basics_url = 'https://datasets.imdbws.com/title.basics.tsv.gz'

akas_url = 'https://datasets.imdbws.com/title.akas.tsv.gz'

ratings_url = 'https://datasets.imdbws.com/title.ratings.tsv.gz'

# %%
# Creating basics df and adding, tab separated and low_memory parameters
# using head to show first 5 row. 

basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# Creating title akas df and adding, tab separated and low_memory parameters
# using head to show first 5 row. 

akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# Creating ratings df and adding, tab separated and low_memory parameters
# using head to show first 5 row. 

ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1910
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1714
# 3  tt0000004            5.6       169
# 4  tt0000005            6.2      2529

# %%
# replacing \N values with NaN
basics.replace({'\\N':np.nan}, inplace=True)

akas.replace({'\\N':np.nan}, inplace=True)

ratings.replace({'\\N':np.nan}, inplace=True)

# %%
# Creating filters for null run time minutes and null genre
run_time = basics['runtimeMinutes'].isna()
no_genre = basics['genres'].isna()

# %%
# dropping the movies that don't have a run time minutes

basics.drop(basics[run_time].index, inplace=True)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# dropping the movies with no genre
basics.drop(basics[no_genre].index, inplace=True)
basics.head()
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_11492\3262967486.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   basics.drop(basics[no_genre].index, inplace=True)
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# Creating filter for start year

start_year = basics['startYear'] < '2000'

basics[start_year].head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# Creating filter for documentary type

doc = basics['genres'].str.contains('documentary', case=False)
basics = basics[~doc]

# %%
# dropping  any movie that had start year before 2000

basics.drop(basics[start_year].index, inplace=True)
basics.head()
# Out:
# C:\Users\dvisi\AppData\Local\Temp\ipykernel_11492\1498964000.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   basics.drop(basics[start_year].index, inplace=True)
#           tconst titleType        primaryTitle       originalTitle isAdult  \
# 33792  tt0034413     short  Youth Gets a Break  Youth Gets a Break       0
# 34792  tt0035423     movie      Kate & Leopold      Kate & Leopold       0
# 39534  tt0040241     short     Color Rhapsodie     Color Rhapsodie       0
# 43538  tt0044326     short           Abstronic           Abstronic       0
# 44080  tt0044879     short             Mandala             Mandala       0
#
#       startYear endYear runtimeMinutes                  genres
# 33792      2001     NaN             20                   Short
# 34792      2001     NaN            118  Comedy,Fantasy,Romance
# 39534      2021     NaN              6                   Short
# 43538      2021     NaN              6                   Short
# 44080      2021     NaN              3                   Short

# %%
# filter for movie title type

film = basics['titleType'] != 'movie'
basics[film].head()
# Out:
#           tconst titleType        primaryTitle       originalTitle isAdult  \
# 33792  tt0034413     short  Youth Gets a Break  Youth Gets a Break       0
# 39534  tt0040241     short     Color Rhapsodie     Color Rhapsodie       0
# 43538  tt0044326     short           Abstronic           Abstronic       0
# 44080  tt0044879     short             Mandala             Mandala       0
# 55741  tt0056840     short            Aufsätze            Aufsätze       0
#
#       startYear endYear runtimeMinutes genres
# 33792      2001     NaN             20  Short
# 39534      2021     NaN              6  Short
# 43538      2021     NaN              6  Short
# 44080      2021     NaN              3  Short
# 55741      2021     NaN             10  Short

# %%
# dropping all non movie title types
basics.drop(basics[film].index, inplace=True)
basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34792  tt0035423     movie                                     Kate & Leopold
# 60162  tt0061366     movie                                   Around the World
# 61093  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67639  tt0069049     movie                         The Other Side of the Wind
# 77933  tt0079644     movie                                      November 1828
#
#                                    originalTitle isAdult startYear endYear  \
# 34792                             Kate & Leopold       0      2001     NaN
# 60162                           Around the World       0       NaN     NaN
# 61093  El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67639                 The Other Side of the Wind       0      2018     NaN
# 77933                              November 1828       0      2001     NaN
#
#       runtimeMinutes                  genres
# 34792            118  Comedy,Fantasy,Romance
# 60162            178          Comedy,Romance
# 61093             70                   Drama
# 67639            122                   Drama
# 77933            140               Drama,War

# %%
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34792      True
# 60162      True
# 61093      True
# 67639      True
# 77933      True
#            ...
# 9228410    True
# 9228419    True
# 9228458    True
# 9228503    True
# 9228587    True
# Name: tconst, Length: 147615, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 60162    tt0061366     movie
# 61093    tt0062336     movie
# 67639    tt0069049     movie
# 77933    tt0079644     movie
# ...            ...       ...
# 9228410  tt9916170     movie
# 9228419  tt9916190     movie
# 9228458  tt9916270     movie
# 9228503  tt9916362     movie
# 9228587  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 60162                                     Around the World
# 61093    The Tango of the Widower and Its Distorting Mi...
# 67639                           The Other Side of the Wind
# 77933                                        November 1828
# ...                                                    ...
# 9228410                                      The Rehearsal
# 9228419                                          Safeguard
# 9228458                           Il talento del calabrone
# 9228503                                              Coven
# 9228587                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34792                               Kate & Leopold       0      2001     NaN
# 60162                             Around the World       0       NaN     NaN
# 61093    El Tango del Viudo y Su Espejo Deformante       0      2020     NaN
# 67639                   The Other Side of the Wind       0      2018     NaN
# 77933                                November 1828       0      2001     NaN
# ...                                            ...     ...       ...     ...
# 9228410                                   O Ensaio       0      2019     NaN
# 9228419                                  Safeguard       0      2020     NaN
# 9228458                   Il talento del calabrone       0      2020     NaN
# 9228503                                   Akelarre       0      2020     NaN
# 9228587                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 60162              178             Comedy,Romance
# 61093               70                      Drama
# 67639              122                      Drama
# 77933              140                  Drama,War
# ...                ...                        ...
# 9228410             51                      Drama
# 9228419             95  Action,Adventure,Thriller
# 9228458             84                   Thriller
# 9228503             92              Drama,History
# 9228587            123                      Drama
#
# [146890 rows x 9 columns]

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

## Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0061366     movie                                   Around the World
# 2  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0079644     movie                                      November 1828
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1                           Around the World        0        NaN      NaN
# 2  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                              November 1828        0     2001.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1             178          Comedy,Romance
# 2              70                   Drama
# 3             122                   Drama
# 4             140               Drama,War

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1910
# 1  tt0000002            5.8       256
# 2  tt0000003            6.5      1714
# 3  tt0000004            5.6       169
# 4  tt0000005            6.2      2529
